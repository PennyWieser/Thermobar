# %%
import numpy as np
import pandas as pd
import sys
sys.path.append("..")
import matplotlib.pyplot as plt
import Thermobar as pt
import sympy as sym
pd.options.display.max_columns = None

# %%
LiqT=pd.DataFrame(data={"SiO2_Liq": 51,
                            "TiO2_Liq": 0.48,
                            "Al2O3_Liq": 19,
                            "FeOt_Liq": 5.3,
                            "MnO_Liq": 0.1,
                            "MgO_Liq": 4.5,
                            "CaO_Liq": 9,
                            "Na2O_Liq": 4.2,
                            "K2O_Liq": 0.1,
                            "Cr2O3_Liq": 0.11,
                            "P2O5_Liq": 0.11,
                            "H2O_Liq": 5,
 "Fe3FeT_Liq":0.1,
}, index=[0])

OpxT=pd.DataFrame(data={"SiO2_Opx": 55,
                            "TiO2_Opx": 0.34,
                            "Al2O3_Opx": 1.5,
                            "FeOt_Opx": 11.3,
                            "MnO_Opx": 0.24,
                            "MgO_Opx": 30.7,
                            "CaO_Opx": 0.9,
                            "Na2O_Opx": 0.01,
                            "K2O_Opx": 0,
                            "Cr2O3_Opx": 0.19}, index=[0])
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pt.calculate_opx_only_press(opx_comps=OpxT, equationP="P_Put2008_eq29c",
         T=1300)
# Out:
# 0    0.631893
# dtype: float64

# %% [markdown]
# ## Opx=liq test

# %%
pt.calculate_opx_liq_temp(opx_comps=OpxT, liq_comps=LiqT, equationT="T_Put2008_eq28b_opx_sat", P=5)
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0    1344.331255
# dtype: float64

# %%
pt.calculate_opx_liq_press(opx_comps=OpxT, liq_comps=LiqT, equationP="P_Put2008_eq29b", T=800)
# Out:
# 0   -21.129189
# dtype: float64

# %%
pt.calculate_opx_liq_press(opx_comps=OpxT, liq_comps=LiqT, equationP="P_Put2008_eq29b", T=800, H2O_Liq=0)
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0   -25.049189
# dtype: float64

# %%
pt.calculate_opx_liq_press(opx_comps=OpxT, liq_comps=LiqT, equationP="P_Put_Global_Opx", T=1300)
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ..\Thermobar\orthopyroxene_thermobarometry.py:246: UserWarning: Youve selected a T-independent function, so your T input doesnt do anything
#   w.warn('Youve selected a T-independent function, so your T input doesnt do anything')
# ..\Thermobar\orthopyroxene_thermobarometry.py:282: UserWarning: Youve selected a T-independent function, so your T input doesnt do anything
#   w.warn('Youve selected a T-independent function, so your T input doesnt do anything')
# 0    1.810153
# dtype: float64

# %%
pt.calculate_opx_liq_press(opx_comps=OpxT, liq_comps=LiqT, equationP="P_Put_Global_Opx", T=1300, eq_tests=True)
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ..\Thermobar\orthopyroxene_thermobarometry.py:282: UserWarning: Youve selected a T-independent function, so your T input doesnt do anything
#   w.warn('Youve selected a T-independent function, so your T input doesnt do anything')
#    SiO2_Liq  P_kbar_calc  Eq_Test_Kd_Fe_Mg_Fet  Eq_Test_Kd_Fe_Mg_Fe2  \
# 0        51     1.810153              0.312519              0.347244
#
#   Kd Eq (Put2008+-0.06)  TiO2_Liq  Al2O3_Liq  FeOt_Liq  MnO_Liq  MgO_Liq  \
# 0                     Y      0.48         19       5.3      0.1      4.5
#
#    CaO_Liq  Na2O_Liq  K2O_Liq  Cr2O3_Liq  P2O5_Liq  H2O_Liq  Fe3FeT_Liq  \
# 0        9       4.2      0.1       0.11      0.11        5         0.1
#
#    SiO2_Liq_mol_frac  MgO_Liq_mol_frac  MnO_Liq_mol_frac  FeOt_Liq_mol_frac  \
# 0            0.58185          0.076535          0.000966           0.050568
#
#    CaO_Liq_mol_frac  Al2O3_Liq_mol_frac  Na2O_Liq_mol_frac  K2O_Liq_mol_frac  \
# 0          0.110016            0.127738           0.046452          0.000728
#
#    TiO2_Liq_mol_frac  P2O5_Liq_mol_frac  Cr2O3_Liq_mol_frac  \
# 0           0.004119           0.000531            0.000496
#
#    SiO2_Liq_cat_frac  MgO_Liq_cat_frac  MnO_Liq_cat_frac  FeOt_Liq_cat_frac  \
# 0           0.494793          0.065084          0.000822           0.043002
#
#    CaO_Liq_cat_frac  Al2O3_Liq_cat_frac  Na2O_Liq_cat_frac  K2O_Liq_cat_frac  \
# 0          0.093555            0.217252           0.079004          0.001238
#
#    TiO2_Liq_cat_frac  P2O5_Liq_cat_frac  Cr2O3_Liq_cat_frac  FeO_Liq_cat_frac  \
# 0           0.003503           0.000904            0.000844          0.038702
#
#    Mg_Number_Liq_NoFe3  Mg_Number_Liq_Fe3  SiO2_Opx  TiO2_Opx  Al2O3_Opx  \
# 0             0.602144           0.627093        55      0.34        1.5
#
#    FeOt_Opx  MnO_Opx  MgO_Opx  CaO_Opx  Na2O_Opx  K2O_Opx  Cr2O3_Opx  \
# 0      11.3     0.24     30.7      0.9      0.01        0       0.19
#
#    SiO2_Opx_cat_6ox  MgO_Opx_cat_6ox  FeOt_Opx_cat_6ox  CaO_Opx_cat_6ox  \
# 0          1.943665         1.617356          0.333959         0.034078
#
#    Al2O3_Opx_cat_6ox  Na2O_Opx_cat_6ox  K2O_Opx_cat_6ox  MnO_Opx_cat_6ox  \
# 0           0.062475          0.000685              0.0         0.007184
#
#    TiO2_Opx_cat_6ox  Cr2O3_Opx_cat_6ox  oxy_renorm_factor_opx  \
# 0          0.009038           0.005308                    0.0
#
#    Al_IV_Opx_cat_6ox  Al_VI_Opx_cat_6ox  Si_Ti_Opx_cat_6ox  Cation_Sum_Opx  \
# 0           0.056335            0.00614           1.952703        4.013748
#
#    NaAlSi2O6  FmTiAlSiO6  CrAl2SiO6  FmAl2SiO6  CaFmSi2O6  Fm2Si2O6    En_Opx  \
# 0   0.000685    0.009038   0.005308   0.000146   0.034078  0.957618  0.790815
#
#      Di_Opx  Mgno_OPX  ln_Fm2Si2O6_liq  ln_FmAl2SiO6_liq  Kd_Fe_Mg_Fet  \
# 0  0.028142   0.82885         5.798439         -2.855529      0.312519
#
#    Kd_Fe_Mg_Fe2  Ideal_Kd  Delta_Kd_Fe_Mg_Fe2  Mgno_Liq_noFe3  Mgno_Liq_Fe2
# 0      0.347244  0.295794             0.05145        0.602144      0.627093

# %%
pt.calculate_opx_liq_press(opx_comps=OpxT, liq_comps=LiqT, equationP="P_Put_Global_Opx", T=1300, eq_tests=True, Fe3FeT_Liq=0.6)
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ..\Thermobar\orthopyroxene_thermobarometry.py:246: UserWarning: Youve selected a T-independent function, so your T input doesnt do anything
#   w.warn('Youve selected a T-independent function, so your T input doesnt do anything')
# ..\Thermobar\orthopyroxene_thermobarometry.py:282: UserWarning: Youve selected a T-independent function, so your T input doesnt do anything
#   w.warn('Youve selected a T-independent function, so your T input doesnt do anything')
#    SiO2_Liq  P_kbar_calc  Eq_Test_Kd_Fe_Mg_Fet  Eq_Test_Kd_Fe_Mg_Fe2  \
# 0        51     1.810153              0.312519              0.781298
#
#   Kd Eq (Put2008+-0.06)  TiO2_Liq  Al2O3_Liq  FeOt_Liq  MnO_Liq  MgO_Liq  \
# 0                     N      0.48         19       5.3      0.1      4.5
#
#    CaO_Liq  Na2O_Liq  K2O_Liq  Cr2O3_Liq  P2O5_Liq  H2O_Liq  Fe3FeT_Liq  \
# 0        9       4.2      0.1       0.11      0.11        5         0.6
#
#    SiO2_Liq_mol_frac  MgO_Liq_mol_frac  MnO_Liq_mol_frac  FeOt_Liq_mol_frac  \
# 0            0.58185          0.076535          0.000966           0.050568
#
#    CaO_Liq_mol_frac  Al2O3_Liq_mol_frac  Na2O_Liq_mol_frac  K2O_Liq_mol_frac  \
# 0          0.110016            0.127738           0.046452          0.000728
#
#    TiO2_Liq_mol_frac  P2O5_Liq_mol_frac  Cr2O3_Liq_mol_frac  \
# 0           0.004119           0.000531            0.000496
#
#    SiO2_Liq_cat_frac  MgO_Liq_cat_frac  MnO_Liq_cat_frac  FeOt_Liq_cat_frac  \
# 0           0.494793          0.065084          0.000822           0.043002
#
#    CaO_Liq_cat_frac  Al2O3_Liq_cat_frac  Na2O_Liq_cat_frac  K2O_Liq_cat_frac  \
# 0          0.093555            0.217252           0.079004          0.001238
#
#    TiO2_Liq_cat_frac  P2O5_Liq_cat_frac  Cr2O3_Liq_cat_frac  FeO_Liq_cat_frac  \
# 0           0.003503           0.000904            0.000844          0.017201
#
#    Mg_Number_Liq_NoFe3  Mg_Number_Liq_Fe3  SiO2_Opx  TiO2_Opx  Al2O3_Opx  \
# 0             0.602144           0.790956        55      0.34        1.5
#
#    FeOt_Opx  MnO_Opx  MgO_Opx  CaO_Opx  Na2O_Opx  K2O_Opx  Cr2O3_Opx  \
# 0      11.3     0.24     30.7      0.9      0.01        0       0.19
#
#    SiO2_Opx_cat_6ox  MgO_Opx_cat_6ox  FeOt_Opx_cat_6ox  CaO_Opx_cat_6ox  \
# 0          1.943665         1.617356          0.333959         0.034078
#
#    Al2O3_Opx_cat_6ox  Na2O_Opx_cat_6ox  K2O_Opx_cat_6ox  MnO_Opx_cat_6ox  \
# 0           0.062475          0.000685              0.0         0.007184
#
#    TiO2_Opx_cat_6ox  Cr2O3_Opx_cat_6ox  oxy_renorm_factor_opx  \
# 0          0.009038           0.005308                    0.0
#
#    Al_IV_Opx_cat_6ox  Al_VI_Opx_cat_6ox  Si_Ti_Opx_cat_6ox  Cation_Sum_Opx  \
# 0           0.056335            0.00614           1.952703        4.013748
#
#    NaAlSi2O6  FmTiAlSiO6  CrAl2SiO6  FmAl2SiO6  CaFmSi2O6  Fm2Si2O6    En_Opx  \
# 0   0.000685    0.009038   0.005308   0.000146   0.034078  0.957618  0.790815
#
#      Di_Opx  Mgno_OPX  ln_Fm2Si2O6_liq  ln_FmAl2SiO6_liq  Kd_Fe_Mg_Fet  \
# 0  0.028142   0.82885         5.798439         -2.855529      0.312519
#
#    Kd_Fe_Mg_Fe2  Ideal_Kd  Delta_Kd_Fe_Mg_Fe2  Mgno_Liq_noFe3  Mgno_Liq_Fe2
# 0      0.781298  0.295794            0.485504        0.602144      0.790956

# %%
pt.calculate_opx_liq_press_temp(opx_comps=OpxT,
       liq_comps=LiqT, equationP="P_Put_Global_Opx", equationT="T_Put2008_eq28a")
# Out:
# ..\Thermobar\orthopyroxene_thermobarometry.py:246: UserWarning: Youve selected a T-independent function, so your T input doesnt do anything
#   w.warn('Youve selected a T-independent function, so your T input doesnt do anything')
# ..\Thermobar\orthopyroxene_thermobarometry.py:282: UserWarning: Youve selected a T-independent function, so your T input doesnt do anything
#   w.warn('Youve selected a T-independent function, so your T input doesnt do anything')
#    P_kbar_calc     T_K_calc
# 0     1.810153  1305.385773

# %%
pt.calculate_opx_liq_press_temp(opx_comps=OpxT,
       liq_comps=LiqT, equationP="P_Put2008_eq29a", equationT="T_Put2008_eq28a")
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    P_kbar_calc     T_K_calc
# 0     2.568279  1308.050269

# %%
pt.calculate_opx_liq_press_temp(opx_comps=OpxT,
       liq_comps=LiqT, equationP="P_Put2008_eq29a", equationT="T_Put2008_eq28a", H2O_Liq=0)
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    P_kbar_calc     T_K_calc
# 0    -0.593182  1364.045732

# %%
Liq2=pd.DataFrame(data={"SiO2_Liq": 51.1,
                            "TiO2_Liq": 0.93,
                            "Al2O3_Liq": 17.5,
                            "FeOt_Liq": 8.91,
                            "MnO_Liq": 0.18,
                            "MgO_Liq": 6.09,
                            "CaO_Liq": 11.50,
                            "Na2O_Liq": 3.53,
                            "K2O_Liq": 0.17,
                            "Cr2O3_Liq": 0,
                            "P2O5_Liq": 0.15,
                            "H2O_Liq": 3.8,
                            "Fe3FeT_Liq":0}, index=[0])

Opx2=pd.DataFrame(data={"SiO2_Opx": 55.00,
                            "TiO2_Opx": 0.34,
                            "Al2O3_Opx": 1.50,
                            "FeOt_Opx": 11.30,
                            "MnO_Opx": 0.24,
                            "MgO_Opx": 30.70,
                            "CaO_Opx": 0.90,
                            "Na2O_Opx": 0.01,
                            "K2O_Opx": 0,
                            "Cr2O3_Opx": 0.19}, index=[0])
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
a=pt.calculate_opx_liq_press_temp_matching(liq_comps=Liq2, opx_comps=Opx2, equationP="P_Put2008_eq29a", 
                                equationT="T_Put2008_eq28a")
a.get("Av_PTs")
# Out:
# C:\Users\penny\anaconda3\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Considering 1 Liq-Opx pairs, be patient if this is >>1 million!
# Finished calculating Ps and Ts, now just averaging the results. Almost there!
# Finished!
#    No. of Cpxs averaged  Mean_Sample_ID_Opx  st_dev_T_K_calc  Mean_T_K_calc  \
# 0                     1                   0              0.0    1384.287957
#
#    st_dev_P_kbar_calc  Mean_P_kbar_calc  Mean_Delta_Kd_Fe_Mg_Fe2  \
# 0                 0.0          3.327589                 0.053295
#
#    Mean_SiO2_Liq  Mean_TiO2_Liq  Mean_Al2O3_Liq  Mean_FeOt_Liq  Mean_MnO_Liq  \
# 0           51.1           0.93            17.5           8.91          0.18
#
#    Mean_MgO_Liq  Mean_CaO_Liq  Mean_Na2O_Liq  Mean_K2O_Liq  Mean_Cr2O3_Liq  \
# 0          6.09          11.5           3.53          0.17             0.0
#
#    Mean_P2O5_Liq  Mean_H2O_Liq  Mean_Fe3FeT_Liq  Mean_Sample_ID_Liq  \
# 0           0.15           3.8              0.0                 0.0
#
#    Mean_SiO2_Liq_mol_frac  Mean_MgO_Liq_mol_frac  Mean_MnO_Liq_mol_frac  \
# 0                 0.53954               0.095858                0.00161
#
#    Mean_FeOt_Liq_mol_frac  Mean_CaO_Liq_mol_frac  Mean_Al2O3_Liq_mol_frac  \
# 0                0.078675               0.130099                 0.108885
#
#    Mean_Na2O_Liq_mol_frac  Mean_K2O_Liq_mol_frac  Mean_TiO2_Liq_mol_frac  \
# 0                0.036132               0.001145                0.007386
#
#    Mean_P2O5_Liq_mol_frac  Mean_Cr2O3_Liq_mol_frac  Mean_SiO2_Liq_cat_frac  \
# 0                 0.00067                      0.0                0.470461
#
#    Mean_MgO_Liq_cat_frac  Mean_MnO_Liq_cat_frac  Mean_FeOt_Liq_cat_frac  \
# 0               0.083585               0.001404                0.068602
#
#    Mean_CaO_Liq_cat_frac  Mean_Al2O3_Liq_cat_frac  Mean_Na2O_Liq_cat_frac  \
# 0               0.113442                 0.189888                0.063012
#
#    Mean_K2O_Liq_cat_frac  Mean_TiO2_Liq_cat_frac  Mean_P2O5_Liq_cat_frac  \
# 0               0.001997                 0.00644                0.001169
#
#    Mean_Cr2O3_Liq_cat_frac  Mean_FeO_Liq_cat_frac  Mean_Mg_Number_Liq_NoFe3  \
# 0                      0.0               0.068602                  0.549218
#
#    Mean_Mg_Number_Liq_Fe3  Mean_ID_Liq  Mean_SiO2_Opx  Mean_TiO2_Opx  \
# 0                0.549218          0.0           55.0           0.34
#
#    Mean_Al2O3_Opx  Mean_FeOt_Opx  Mean_MnO_Opx  Mean_MgO_Opx  Mean_CaO_Opx  \
# 0             1.5           11.3          0.24          30.7           0.9
#
#    Mean_Na2O_Opx  Mean_K2O_Opx  Mean_Cr2O3_Opx  Mean_SiO2_Opx_cat_6ox  \
# 0           0.01           0.0            0.19               1.943665
#
#    Mean_MgO_Opx_cat_6ox  Mean_FeOt_Opx_cat_6ox  Mean_CaO_Opx_cat_6ox  \
# 0              1.617356               0.333959              0.034078
#
#    Mean_Al2O3_Opx_cat_6ox  Mean_Na2O_Opx_cat_6ox  Mean_K2O_Opx_cat_6ox  \
# 0                0.062475               0.000685                   0.0
#
#    Mean_MnO_Opx_cat_6ox  Mean_TiO2_Opx_cat_6ox  Mean_Cr2O3_Opx_cat_6ox  \
# 0              0.007184               0.009038                0.005308
#
#    Mean_oxy_renorm_factor_opx  Mean_Al_IV_Opx_cat_6ox  Mean_Al_VI_Opx_cat_6ox  \
# 0                         0.0                0.056335                 0.00614
#
#    Mean_Si_Ti_Opx_cat_6ox  Mean_Cation_Sum_Opx  Mean_NaAlSi2O6  \
# 0                1.952703             4.013748        0.000685
#
#    Mean_FmTiAlSiO6  Mean_CrAl2SiO6  Mean_FmAl2SiO6  Mean_CaFmSi2O6  \
# 0         0.009038        0.005308        0.000146        0.034078
#
#    Mean_Fm2Si2O6  Mean_En_Opx  Mean_Di_Opx  Mean_Mgno_OPX  Mean_ID_OPX  \
# 0       0.957618     0.790815     0.028142        0.82885          0.0
#
#    Mean_ln_Fm2Si2O6_liq  Mean_ln_FmAl2SiO6_liq  Mean_Kd_Fe_Mg_Fet  \
# 0              5.211708              -2.879647           0.251582
#
#    Mean_Kd_Fe_Mg_Fe2  Mean_Ideal_Kd  Mean_Mgno_Liq_noFe3  Mean_Mgno_Liq_Fe2
# 0           0.251582       0.304877             0.549218           0.549218

# %%
pt.calculate_opx_rhodes_diagram_lines(Min_Mgno=0.4, Max_Mgno=0.7, liq_comps=Liq2)
# Out:
#      Mg#_Liq  Eq_Opx_Mg# (Kd=0.23)  Eq_Opx_Mg# (Kd=0.29)  \
# 0   0.400000              0.743494              0.696864
# 1   0.403030              0.745892              0.699521
# 2   0.406061              0.748269              0.702159
# 3   0.409091              0.750626              0.704777
# 4   0.412121              0.752962              0.707375
# ..       ...                   ...                   ...
# 95  0.687879              0.905501              0.883715
# 96  0.690909              0.906705              0.885162
# 97  0.693939              0.907902              0.886600
# 98  0.696970              0.909091              0.888031
# 99  0.700000              0.910273              0.889454
#
#     Eq_Opx_Mg# (Kd=0.35)  Kd_XSi_P2008  Eq_Opx_Mg# (Kd_XSi_P2008)  \
# 0               0.655738      0.304877                   0.686193
# 1               0.658579      0.304877                   0.688902
# 2               0.661402      0.304877                   0.691592
# 3               0.664207      0.304877                   0.694262
# 4               0.666994      0.304877                   0.696914
# ..                   ...           ...                        ...
# 95              0.862954      0.304877                   0.878475
# 96              0.864619      0.304877                   0.879978
# 97              0.866276      0.304877                   0.881472
# 98              0.867925      0.304877                   0.882959
# 99              0.869565      0.304877                   0.884438
#
#     Eq_Opx_Mg# (Kd_XSi_P2008)+0.06  Eq_Opx_Mg# (Kd_XSi_P2008)-0.06
# 0                         0.646281                        0.731360
# 1                         0.649158                        0.733831
# 2                         0.652018                        0.736280
# 3                         0.654860                        0.738710
# 4                         0.657684                        0.741120
# ..                             ...                             ...
# 95                        0.857956                        0.900000
# 96                        0.859672                        0.901266
# 97                        0.861380                        0.902525
# 98                        0.863079                        0.903777
# 99                        0.864771                        0.905021
#
# [100 rows x 8 columns]
