# %% [markdown]
# # This script shows our Leake classification diagram matches that of Putirka

# %%
import numpy as np
import pandas as pd
import Thermobar as pt#
pd.options.display.max_columns = None
import matplotlib.pyplot as plt

# %%
out=pt.import_excel('Python_Amphiboles_Test.xlsx', sheet_name="Putirka_Benchmarks")
my_input=out['my_input']
myAmps1=out['Amps']
myLiquids1=out['Liqs']

# %%
out2=pt.import_excel('Leake_Site_Example.xlsx', sheet_name="Sheet1")
my_input2=out2['my_input']
myAmps2=out2['Amps']
myLiquids2=out2['Liqs']

# %%
my_input2
# Out:
#   Sample_ID_Amp  SiO2_Amp  TiO2_Amp  Al2O3_Amp  Cr2O3_Amp  FeOt_Amp  MnO_Amp  \
# 0        Leake1     51.63         0       7.39          0      7.55     0.17
# 1         test2     51.63         0       7.39          0      7.55     0.17
# 2         test3     60.00         5       7.39          4      0.00     0.17
# 3         test4     40.00         5       3.00          4      3.00     0.00
# 4         test5     40.00         5       3.00          4      3.00     0.00
# 5         test6     51.63         0       7.39          0      7.55     0.17
# 6         test7     51.63         0       7.39          5      7.55     0.17
# 7         test8     51.63         0       7.39          0      7.55     0.17
# 8         test9     51.63         0       7.39          0      0.00     0.17
# 9        test10     51.63        10       7.39          0      7.55     0.17
#
#    MgO_Amp  CaO_Amp  Na2O_Amp  K2O_Amp  \
# 0    18.09    12.32      0.61        0
# 1    18.09     0.00      0.00        0
# 2    18.09     0.00      0.00        0
# 3     5.00    20.00      1.00        1
# 4     5.00    20.00      1.00        1
# 5    18.09    12.32      0.00        0
# 6    18.09    12.32      0.61        0
# 7     0.00    12.32      0.61        0
# 8    18.09    12.32      0.61        0
# 9    18.09    12.32      0.61        0
#
#                                   Unnamed: 11
# 0                                         NaN
# 1  *This is me checking sums are always right
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                 *Deleted Na
# 6                                  * Added Cr
# 7                               * deleted MgO
# 8                               * deleted FeO
# 9                         * aded tonnes of Ti

# %%
amp_apfu_df2=pt.calculate_23oxygens_amphibole(amp_comps=myAmps2)
sites_jordan=pt.get_amp_sites(amp_apfu_df2)
sites_penny=pt.get_amp_sites2(amp_apfu_df2)

# %%
# %%time
sites_jordan
# Out:
# Wall time: 0 ns
#    SiO2_Amp_cat_23ox  MgO_Amp_cat_23ox  FeOt_Amp_cat_23ox  CaO_Amp_cat_23ox  \
# 0           7.261070          3.792675           0.887976          1.856446
# 1           7.929797          4.141971           0.969757          0.000000
# 2           8.002697          3.596932           0.000000          0.000000
# 3           7.046131          1.313014           0.441945          3.774799
# 4           7.046131          1.313014           0.441945          3.774799
# 5           7.287421          3.806439           0.891199          1.863183
# 6           7.007021          3.659977           0.856908          1.791493
# 7           8.694839          0.000000           1.063316          2.223020
# 8           7.552661          3.944981           0.000000          1.930997
# 9           6.649406          3.473184           0.813174          1.700061
#
#    Al2O3_Amp_cat_23ox  Na2O_Amp_cat_23ox  K2O_Amp_cat_23ox  MnO_Amp_cat_23ox  \
# 0            1.224898           0.166332          0.000000          0.020250
# 1            1.337708           0.000000          0.000000          0.022115
# 2            1.161680           0.000000          0.000000          0.019205
# 3            0.622829           0.341537          0.224724          0.000000
# 4            0.622829           0.341537          0.224724          0.000000
# 5            1.229343           0.000000          0.000000          0.020324
# 6            1.182041           0.160512          0.000000          0.019542
# 7            1.466766           0.199176          0.000000          0.024249
# 8            1.274087           0.173011          0.000000          0.021064
# 9            1.121714           0.152320          0.000000          0.018544
#
#    TiO2_Amp_cat_23ox  Cr2O3_Amp_cat_23ox  oxy_renorm_factor  cation_sum_Si_Mg  \
# 0           0.000000            0.000000                0.0         13.186869
# 1           0.000000            0.000000                0.0         14.401349
# 2           0.501631            0.421791                0.0         13.703936
# 3           0.662507            0.557062                0.0         10.643487
# 4           0.662507            0.557062                0.0         10.643487
# 5           0.000000            0.000000                0.0         13.234725
# 6           0.000000            0.536480                0.0         13.261969
# 7           0.000000            0.000000                0.0         11.249170
# 8           0.000000            0.000000                0.0         12.792793
# 9           0.968747            0.000000                0.0         13.044769
#
#    cation_sum_Si_Ca  cation_sum_All  Mgno_Amp      Si_T      Al_T      Al_C  \
# 0         15.043315       15.209647  0.810288  7.261070  0.738930  0.485968
# 1         14.401349       14.401349  0.810288  7.929797  0.070203  1.267505
# 2         13.703936       13.703936  1.000000  8.002697  0.000000  1.161680
# 3         14.418286       14.984547  0.748174  7.046131  0.622829  0.000000
# 4         14.418286       14.984547  0.748174  7.046131  0.622829  0.000000
# 5         15.097908       15.097908  0.810288  7.287421  0.712579  0.516764
# 6         15.053462       15.213975  0.810288  7.007021  0.992979  0.189062
# 7         13.472190       13.671366  0.000000  8.694839  0.000000  1.466766
# 8         14.723790       14.896802  1.000000  7.552661  0.447339  0.826748
# 9         14.744831       14.897151  0.810288  6.649406  1.121714  0.000000
#
#        Ti_C      Mg_C      Fe_C      Mn_C      Cr_C      Mg_B      Fe_B  \
# 0  0.000000  3.792675  0.721358  0.000000  0.000000  0.000000  0.166619
# 1  0.000000  3.732495  0.000000  0.000000  0.000000  0.409476  0.969757
# 2  0.501631  2.914898  0.000000  0.000000  0.421791  0.682034  0.000000
# 3  0.662507  1.313014  0.441945  0.000000  0.557062  0.000000  0.000000
# 4  0.662507  1.313014  0.441945  0.000000  0.557062  0.000000  0.000000
# 5  0.000000  3.806439  0.676798  0.000000  0.000000  0.000000  0.214401
# 6  0.000000  3.659977  0.614480  0.000000  0.536480  0.000000  0.242428
# 7  0.000000  0.000000  1.063316  0.024249  0.000000  0.000000  0.000000
# 8  0.000000  3.944981  0.000000  0.021064  0.000000  0.000000  0.000000
# 9  0.968747  3.473184  0.558069  0.000000  0.000000  0.000000  0.255105
#
#        Mn_B      Na_B      Ca_B      Na_A       K_A     Sum_T     Sum_C  \
# 0  0.020250  0.000000  1.856446  0.166332  0.000000  8.000000  5.000000
# 1  0.022115  0.000000  0.000000  0.000000  0.000000  8.000000  5.000000
# 2  0.019205  0.000000  0.000000  0.000000  0.000000  8.002697  4.498369
# 3  0.000000  0.000000  3.774799  0.341537  0.224724  7.668960  2.312020
# 4  0.000000  0.000000  3.774799  0.341537  0.224724  7.668960  2.312020
# 5  0.020324  0.000000  1.863183  0.000000  0.000000  8.000000  5.000000
# 6  0.019542  0.000000  1.791493  0.160512  0.000000  8.000000  5.000000
# 7  0.000000  0.000000  2.223020  0.199176  0.000000  8.694839  2.554331
# 8  0.000000  0.069003  1.930997  0.104009  0.000000  8.000000  4.792793
# 9  0.018544  0.026289  1.700061  0.126031  0.000000  7.771120  4.031253
#
#       Sum_B     Sum_A
# 0  2.043315  0.166332
# 1  1.401349  0.000000
# 2  0.701240  0.000000
# 3  3.774799  0.566261
# 4  3.774799  0.566261
# 5  2.097908  0.000000
# 6  2.053462  0.160512
# 7  2.223020  0.199176
# 8  2.000000  0.104009
# 9  2.000000  0.126031

# %%
# %%time
sites_penny
# Out:
# Wall time: 0 ns
#        Si_T      Al_T      Al_C      Ti_C      Mg_C      Fe_C  Mn_C      Cr_C  \
# 0  7.261070  0.738930  0.485968  0.000000  3.792675  0.721358   0.0  0.000000
# 1  7.929797  0.070203  1.267505  0.000000  3.732495  0.000000   0.0  0.000000
# 2  8.002697 -0.002697  1.164377  0.501631  4.759046  0.000000   0.0  0.421791
# 3  7.046131  0.622829  0.000000  0.662507  1.313014  2.467418   0.0  0.557062
# 4  7.046131  0.622829  0.000000  0.662507  1.313014  2.467418   0.0  0.557062
# 5  7.287421  0.712579  0.516764  0.000000  3.806439  0.676798   0.0  0.000000
# 6  7.007021  0.992979  0.189062  0.000000  3.659977  0.614480   0.0  0.536480
# 7  8.694839 -0.694839  2.161605  0.000000  0.000000  2.838395   0.0  0.000000
# 8  7.552661  0.447339  0.826748  0.000000  3.944981  0.228271   0.0  0.000000
# 9  6.649406  1.121714  0.000000  0.968747  3.473184  0.558069   0.0  0.000000
#
#        Mg_B      Fe_B      Mn_B      Na_B      Ca_B      Na_A       K_A  \
# 0  0.000000  0.166619  0.020250  0.000000  1.856446  0.166332  0.000000
# 1  0.409476  0.969757  0.022115  0.598651  0.000000 -0.598651  0.000000
# 2  0.684731  0.000000  0.019205  1.296064  0.000000 -1.296064  0.000000
# 3  0.000000 -2.025473  0.000000  0.250674  3.774799  0.090863  0.224724
# 4  0.000000 -2.025473  0.000000  0.250674  3.774799  0.090863  0.224724
# 5  0.000000  0.214401  0.020324  0.000000  1.863183  0.000000  0.000000
# 6  0.000000  0.242428  0.019542  0.000000  1.791493  0.160512  0.000000
# 7  0.000000 -1.775079  0.024249  1.527810  2.223020 -1.328634  0.000000
# 8  0.000000 -0.228271  0.021064  0.276210  1.930997 -0.103198  0.000000
# 9  0.000000  0.255105  0.018544  0.026289  1.700061  0.126031  0.000000
#
#      Sum_T     Sum_C     Sum_B     Sum_A
# 0  8.00000  5.000000  2.043315  0.166332
# 1  8.00000  5.000000  2.000000 -0.598651
# 2  8.00000  6.345214  2.000000 -1.296064
# 3  7.66896  4.337493  2.000000  0.315587
# 4  7.66896  4.337493  2.000000  0.315587
# 5  8.00000  5.000000  2.097908  0.000000
# 6  8.00000  5.000000  2.053462  0.160512
# 7  8.00000  5.000000  2.000000 -1.328634
# 8  8.00000  5.000000  2.000000 -0.103198
# 9  7.77112  4.031253  2.000000  0.126031

# %%
plt.plot(sites_jordan['Na_B'], sites_penny['Na_B'], 'ok')

# %%
plt.plot(sites_jordan['Fe_B'], sites_penny['Fe_B'], 'ok')

# %%
site=sites_jordan
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(2,2, figsize = (12,5)) # adjust dimensions of figure here
ax0.plot(amp_apfu_df2['MgO_Amp_cat_23ox'], site['Mg_C']+site['Mg_B'], 'ok')
ax0.plot([0, 5], [0, 5], '-r')

ax1.plot(amp_apfu_df2['FeOt_Amp_cat_23ox'], site['Fe_C']+site['Fe_B'], 'ok')
ax1.plot([0, 5], [0, 5], '-r')

ax2.plot(amp_apfu_df2['Na2O_Amp_cat_23ox'], site['Na_B']+site['Na_A'], 'ok')
ax2.plot([0, 5], [0, 5], '-r')

# %%
plt.plot(sites_jordan['Sum_B'], sites_penny['Sum_B'], 'ok')

# %%
amp_apfu_df1=pt.calculate_23oxygens_amphibole(amp_comps=myAmps1)
sites_jordan1=pt.get_amp_sites(amp_apfu_df1)
sites_penny1=pt.get_amp_sites2(amp_apfu_df1)

# %%
plt.plot(sites_jordan1['Na_B'], sites_penny1['Na_B'], 'ok')

# %%
Leake_Sites=pd.DataFrame(data={"Si_T": 7.261, 
                              "Al_T": 0.739,
                              "Al_C": 0.486,
                              "Cr_C": 0,
                              "Mg_C": 3.793,
                              "Fe_C": 0.721,
                              "Mn_C": 0,
                              "Mg_B":0,
                              "Fe_B":0.167,
                               "Mn_B": 0.02,
                               "Ca_B": 1.856,
                              "Na_B": 0,
                              "Na_A": 0.166,
                              "K_A": 0.166}, index=[0])

# %%
#Leake is 7.261, 0.739, Al C = 0.486, 
sites_jordan
# Out:
#    SiO2_Amp_cat_23ox  MgO_Amp_cat_23ox  FeOt_Amp_cat_23ox  CaO_Amp_cat_23ox  \
# 0           7.261070          3.792675           0.887976          1.856446
# 1           7.929797          4.141971           0.969757          0.000000
# 2           8.002697          3.596932           0.000000          0.000000
# 3           7.046131          1.313014           0.441945          3.774799
# 4           7.046131          1.313014           0.441945          3.774799
# 5           7.287421          3.806439           0.891199          1.863183
# 6           7.007021          3.659977           0.856908          1.791493
# 7           8.694839          0.000000           1.063316          2.223020
# 8           7.552661          3.944981           0.000000          1.930997
# 9           6.649406          3.473184           0.813174          1.700061
#
#    Al2O3_Amp_cat_23ox  Na2O_Amp_cat_23ox  K2O_Amp_cat_23ox  MnO_Amp_cat_23ox  \
# 0            1.224898           0.166332          0.000000          0.020250
# 1            1.337708           0.000000          0.000000          0.022115
# 2            1.161680           0.000000          0.000000          0.019205
# 3            0.622829           0.341537          0.224724          0.000000
# 4            0.622829           0.341537          0.224724          0.000000
# 5            1.229343           0.000000          0.000000          0.020324
# 6            1.182041           0.160512          0.000000          0.019542
# 7            1.466766           0.199176          0.000000          0.024249
# 8            1.274087           0.173011          0.000000          0.021064
# 9            1.121714           0.152320          0.000000          0.018544
#
#    TiO2_Amp_cat_23ox  Cr2O3_Amp_cat_23ox  oxy_renorm_factor  cation_sum_Si_Mg  \
# 0           0.000000            0.000000                0.0         13.186869
# 1           0.000000            0.000000                0.0         14.401349
# 2           0.501631            0.421791                0.0         13.703936
# 3           0.662507            0.557062                0.0         10.643487
# 4           0.662507            0.557062                0.0         10.643487
# 5           0.000000            0.000000                0.0         13.234725
# 6           0.000000            0.536480                0.0         13.261969
# 7           0.000000            0.000000                0.0         11.249170
# 8           0.000000            0.000000                0.0         12.792793
# 9           0.968747            0.000000                0.0         13.044769
#
#    cation_sum_Si_Ca  cation_sum_All  Mgno_Amp      Si_T      Al_T      Al_C  \
# 0         15.043315       15.209647  0.810288  7.261070  0.738930  0.485968
# 1         14.401349       14.401349  0.810288  7.929797  0.070203  1.267505
# 2         13.703936       13.703936  1.000000  8.002697  0.000000  1.161680
# 3         14.418286       14.984547  0.748174  7.046131  0.622829  0.000000
# 4         14.418286       14.984547  0.748174  7.046131  0.622829  0.000000
# 5         15.097908       15.097908  0.810288  7.287421  0.712579  0.516764
# 6         15.053462       15.213975  0.810288  7.007021  0.992979  0.189062
# 7         13.472190       13.671366  0.000000  8.694839  0.000000  1.466766
# 8         14.723790       14.896802  1.000000  7.552661  0.447339  0.826748
# 9         14.744831       14.897151  0.810288  6.649406  1.121714  0.000000
#
#        Ti_C      Mg_C      Fe_C      Mn_C      Cr_C      Mg_B      Fe_B  \
# 0  0.000000  3.792675  0.721358  0.000000  0.000000  0.000000  0.166619
# 1  0.000000  3.732495  0.000000  0.000000  0.000000  0.409476  0.969757
# 2  0.501631  2.914898  0.000000  0.000000  0.421791  0.682034  0.000000
# 3  0.662507  1.313014  0.441945  0.000000  0.557062  0.000000  0.000000
# 4  0.662507  1.313014  0.441945  0.000000  0.557062  0.000000  0.000000
# 5  0.000000  3.806439  0.676798  0.000000  0.000000  0.000000  0.214401
# 6  0.000000  3.659977  0.614480  0.000000  0.536480  0.000000  0.242428
# 7  0.000000  0.000000  1.063316  0.024249  0.000000  0.000000  0.000000
# 8  0.000000  3.944981  0.000000  0.021064  0.000000  0.000000  0.000000
# 9  0.968747  3.473184  0.558069  0.000000  0.000000  0.000000  0.255105
#
#        Mn_B      Na_B      Ca_B      Na_A       K_A     Sum_T     Sum_C  \
# 0  0.020250  0.000000  1.856446  0.166332  0.000000  8.000000  5.000000
# 1  0.022115  0.000000  0.000000  0.000000  0.000000  8.000000  5.000000
# 2  0.019205  0.000000  0.000000  0.000000  0.000000  8.002697  4.498369
# 3  0.000000  0.000000  3.774799  0.341537  0.224724  7.668960  2.312020
# 4  0.000000  0.000000  3.774799  0.341537  0.224724  7.668960  2.312020
# 5  0.020324  0.000000  1.863183  0.000000  0.000000  8.000000  5.000000
# 6  0.019542  0.000000  1.791493  0.160512  0.000000  8.000000  5.000000
# 7  0.000000  0.000000  2.223020  0.199176  0.000000  8.694839  2.554331
# 8  0.000000  0.069003  1.930997  0.104009  0.000000  8.000000  4.792793
# 9  0.018544  0.026289  1.700061  0.126031  0.000000  7.771120  4.031253
#
#       Sum_B     Sum_A
# 0  2.043315  0.166332
# 1  1.401349  0.000000
# 2  0.701240  0.000000
# 3  3.774799  0.566261
# 4  3.774799  0.566261
# 5  2.097908  0.000000
# 6  2.053462  0.160512
# 7  2.223020  0.199176
# 8  2.000000  0.104009
# 9  2.000000  0.126031

# %%
sites_penny
# Out:
#        Si_T      Al_T      Al_C      Ti_C      Mg_C      Fe_C  Mn_C      Cr_C  \
# 0  7.261070  0.738930  0.485968  0.000000  3.792675  0.721358   0.0  0.000000
# 1  7.929797  0.070203  1.267505  0.000000  3.732495  0.000000   0.0  0.000000
# 2  8.002697 -0.002697  1.164377  0.501631  4.759046  0.000000   0.0  0.421791
# 3  7.046131  0.622829  0.000000  0.662507  1.313014  2.467418   0.0  0.557062
# 4  7.046131  0.622829  0.000000  0.662507  1.313014  2.467418   0.0  0.557062
# 5  7.287421  0.712579  0.516764  0.000000  3.806439  0.676798   0.0  0.000000
# 6  7.007021  0.992979  0.189062  0.000000  3.659977  0.614480   0.0  0.536480
# 7  8.694839 -0.694839  2.161605  0.000000  0.000000  2.838395   0.0  0.000000
# 8  7.552661  0.447339  0.826748  0.000000  3.944981  0.228271   0.0  0.000000
# 9  6.649406  1.121714  0.000000  0.968747  3.473184  0.558069   0.0  0.000000
#
#        Mg_B      Fe_B      Mn_B      Na_B      Ca_B      Na_A       K_A  \
# 0  0.000000  0.166619  0.020250  0.000000  1.856446  0.166332  0.000000
# 1  0.409476  0.969757  0.022115  0.598651  0.000000 -0.598651  0.000000
# 2  0.684731  0.000000  0.019205  1.296064  0.000000 -1.296064  0.000000
# 3  0.000000 -2.025473  0.000000  0.250674  3.774799  0.090863  0.224724
# 4  0.000000 -2.025473  0.000000  0.250674  3.774799  0.090863  0.224724
# 5  0.000000  0.214401  0.020324  0.000000  1.863183  0.000000  0.000000
# 6  0.000000  0.242428  0.019542  0.000000  1.791493  0.160512  0.000000
# 7  0.000000 -1.775079  0.024249  1.527810  2.223020 -1.328634  0.000000
# 8  0.000000 -0.228271  0.021064  0.276210  1.930997 -0.103198  0.000000
# 9  0.000000  0.255105  0.018544  0.026289  1.700061  0.126031  0.000000
#
#      Sum_T     Sum_C     Sum_B     Sum_A
# 0  8.00000  5.000000  2.043315  0.166332
# 1  8.00000  5.000000  2.000000 -0.598651
# 2  8.00000  6.345214  2.000000 -1.296064
# 3  7.66896  4.337493  2.000000  0.315587
# 4  7.66896  4.337493  2.000000  0.315587
# 5  8.00000  5.000000  2.097908  0.000000
# 6  8.00000  5.000000  2.053462  0.160512
# 7  8.00000  5.000000  2.000000 -1.328634
# 8  8.00000  5.000000  2.000000 -0.103198
# 9  7.77112  4.031253  2.000000  0.126031

# %%
sites_jordan['Si_T']/sites_penny['Si_T']
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    1.0
# 8    1.0
# 9    1.0
# Name: Si_T, dtype: float64

# %%
sites_jordan['Ca_B']/sites_penny['Ca_B']
# Out:
# 0    1.0
# 1    NaN
# 2    NaN
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    1.0
# 8    1.0
# 9    1.0
# Name: Ca_B, dtype: float64

# %%
sites_jordan['Mg_C']/sites_penny['Mg_C']
# Out:
# 0    1.000000
# 1    1.000000
# 2    0.612496
# 3    1.000000
# 4    1.000000
# 5    1.000000
# 6    1.000000
# 7         NaN
# 8    1.000000
# 9    1.000000
# Name: Mg_C, dtype: float64

# %% [markdown]
# ## Calculate Leake Classification

# %%
pt.plot_amp_class_Leake(amp_comps=myAmps1, text_labels=True, lower_text=0.2, upper_text=0.8, 
                        site_check=False)
# Out:
# <ipython-input-20-7652c5de233a>:1: UserWarning: 6 of your amphiboles have Na_A+K_A>0.5 so shouldnt be plotted on this diagram based on Leake. site_check=True filters these out
#   pt.plot_amp_class_Leake(amp_comps=myAmps1, text_labels=True, lower_text=0.2, upper_text=0.8,

# %%
pt.plot_amp_class_Leake(amp_comps=myAmps1, text_labels=True, lower_text=0.2, upper_text=0.8, 
                        site_check=True)
# Out:
# 0 amphiboles have Ca_B<1.5, so arent shown on this plot
# 6 amphiboles have Na_A+K_A<1.5, so arent shown on this plot

# %%
pt.plot_amp_class_Leake(amp_comps=myAmps1, text_labels=False, lower_text=0.2, upper_text=0.8)

# %%
cat_23ox=pt.calculate_23oxygens_amphibole(amp_comps=myAmps1)
cat_23ox.head()
# Out:
#    SiO2_Amp_cat_23ox  MgO_Amp_cat_23ox  FeOt_Amp_cat_23ox  CaO_Amp_cat_23ox  \
# 0           6.088253          2.912777           1.645305          1.869995
# 1           6.399508          2.737503           1.607585          1.901472
# 2           5.891052          2.918512           1.837141          1.784078
# 3           6.289313          3.010500           1.632744          1.767712
# 4           6.441589          2.951988           1.569270          1.778037
#
#    Al2O3_Amp_cat_23ox  Na2O_Amp_cat_23ox  K2O_Amp_cat_23ox  MnO_Amp_cat_23ox  \
# 0            2.267423           0.640114          0.176130          0.033048
# 1            2.064811           0.641619          0.155210          0.000000
# 2            2.312188           0.647279          0.206813          0.062837
# 3            1.949713           0.655939          0.180623          0.049231
# 4            1.891861           0.646588          0.166919          0.025679
#
#    TiO2_Amp_cat_23ox  Cr2O3_Amp_cat_23ox  oxy_renorm_factor  cation_sum_Si_Mg  \
# 0           0.276556            0.000000                0.0         13.223362
# 1           0.229397            0.000000                0.0         13.038803
# 2           0.357556            0.003258                0.0         13.382545
# 3           0.308285            0.001178                0.0         13.240963
# 4           0.273652            0.000000                0.0         13.154038
#
#    cation_sum_Si_Ca  cation_sum_All  Mgno_Amp
# 0         15.093357       15.909602  0.639036
# 1         14.940276       15.737104  0.630022
# 2         15.166623       16.020715  0.613693
# 3         15.008675       15.845238  0.648361
# 4         14.932075       15.745582  0.652913

# %%
fig, (ax1) = plt.subplots( figsize = (8,5), sharey=True, sharex=True)

ax1.plot(cat_23ox['SiO2_Amp_cat_23ox'], cat_23ox['Mgno_Amp'], 'ok')
pt.add_Leake_Amp_Fields(ax1)
ax1.invert_xaxis()
ax1.set_xlabel('Si (apfu)')
ax1.set_ylabel('Mg# Amphibole')
# Out:
# Text(0, 0.5, 'Mg# Amphibole')

# %%
cat_23ox['Mgno_Amp']
# Out:
# 0     0.639036
# 1     0.630022
# 2     0.613693
# 3     0.648361
# 4     0.652913
# 5     0.626531
# 6     0.639233
# 7     0.640623
# 8     0.628083
# 9     0.655561
# 10    0.656040
# 11    0.648025
# 12    0.639036
# 13    0.630022
# 14    0.613693
# 15    0.664265
# 16    0.687647
# 17    0.687647
# 18    0.563908
# 19    0.526254
# 20    0.482702
# 21    0.421583
# Name: Mgno_Amp, dtype: float64

# %%
test=pd.DataFrame(data={})

# %%
Class_lines=[7.5, 8]
