# %%
import numpy as np
import pandas as pd
import Thermobar as pt#
pd.options.display.max_columns = None
pd.options.display.max_rows = None
import matplotlib.pyplot as plt

# %%
# This dataset contains a lot of amphiboles which throw up errors
out=pt.import_excel('Errors_Ridolfi.xlsx', sheet_name="Numbers")
my_input=out['my_input']
myAmps1=out['Amps']
myLiquids1=out['Liqs']

# %%
# name=pt.calculate_sites_ridolfi(amp_comps=myAmps1).classification
# name.to_clipboard(excel=True)

# %% [markdown]
# ## Testing sites

# %%
Sites=pt.calculate_sites_ridolfi(amp_comps=myAmps1)
Sites.head()
# Out:
#    SiO2_Amp_cat_prop  MgO_Amp_cat_prop  FeOt_Amp_cat_prop  CaO_Amp_cat_prop  \
# 0           0.706178          0.386066           0.108566          0.199897
# 1           0.685540          0.388795           0.131392          0.205781
# 2           0.760435          0.361503           0.186092          0.191159
# 3           0.758272          0.375893           0.170782          0.196687
# 4           0.759770          0.352570           0.185118          0.192764
#
#    Al2O3_Amp_cat_prop  Na2O_Amp_cat_prop  K2O_Amp_cat_prop  MnO_Amp_cat_prop  \
# 0            0.254411           0.077768          0.034184          0.001269
# 1            0.240288           0.078736          0.029726          0.001551
# 2            0.189092           0.056793          0.004883          0.002960
# 3            0.204000           0.060988          0.005308          0.002960
# 4            0.211453           0.060988          0.005733          0.002960
#
#    TiO2_Amp_cat_prop  Cr2O3_Amp_cat_prop  F_Amp_cat_prop  Cl_Amp_cat_prop  \
# 0           0.031290            0.004079             0.0              0.0
# 1           0.032792            0.001316             0.0              0.0
# 2           0.018023            0.000000             0.0              0.0
# 3           0.017898            0.000000             0.0              0.0
# 4           0.019400            0.000000             0.0              0.0
#
#    SiO2_Amp_13_cat  MgO_Amp_13_cat  FeOt_Amp_13_cat  CaO_Amp_13_cat  \
# 0         6.153610        3.364164         0.946036        1.741892
# 1         6.014835        3.411235         1.152816        1.805495
# 2         6.511839        3.095656         1.593566        1.636952
# 3         6.443655        3.194272         1.451274        1.671409
# 4         6.450198        2.993209         1.571593        1.636502
#
#    Al2O3_Amp_13_cat  Na2O_Amp_13_cat  K2O_Amp_13_cat  MnO_Amp_13_cat  \
# 0          2.216928         0.677670        0.297882        0.011056
# 1          2.108253         0.690822        0.260808        0.013605
# 2          1.619251         0.486339        0.041819        0.025351
# 3          1.733551         0.518268        0.045108        0.025157
# 4          1.795171         0.517772        0.048670        0.025133
#
#    TiO2_Amp_13_cat  Cr2O3_Amp_13_cat  F_Amp_13_cat  Cl_Amp_13_cat  \
# 0         0.272659          0.035546           0.0            0.0
# 1         0.287711          0.011545           0.0            0.0
# 2         0.154336          0.000000           0.0            0.0
# 3         0.152092          0.000000           0.0            0.0
# 4         0.164697          0.000000           0.0            0.0
#
#    cation_sum_Si_Mg      Si_T   Al_IV_T  Ti_T      Cr_C     Fe3_C      Mg_C  \
# 0          1.491858  6.153610  1.846390   0.0  0.035546  0.435652  3.364164
# 1          1.481674  6.014835  1.985165   0.0  0.011545  0.712491  3.411235
# 2          1.518106  6.511839  1.488161   0.0  0.000000  1.246336  3.095656
# 3          1.529805  6.443655  1.556345   0.0  0.000000  1.168762  3.194272
# 4          1.531272  6.450198  1.549802   0.0  0.000000  1.135595  2.993209
#
#       Fe2_C      Mn_C      Ca_B      Na_B      Na_A       K_A   Al_VI_C  \
# 0  0.510384  0.011056  1.741892  0.258108  0.419562  0.297882  0.370538
# 1  0.440325  0.013605  1.805495  0.194505  0.496317  0.260808  0.123088
# 2  0.347230  0.025351  1.636952  0.363048  0.123291  0.041819  0.131090
# 3  0.282511  0.025157  1.671409  0.328591  0.189677  0.045108  0.177205
# 4  0.435999  0.025133  1.636502  0.363498  0.154274  0.048670  0.245368
#
#        Ti_C     Charge  Sum_input  H2O_calc  Fe3_calc  Fe2_calc  Fe2O3_calc  \
# 0  0.272659  45.564348      96.89  1.950892  0.435652  0.510384    3.991855
# 1  0.287711  45.287509      96.76  1.937574  0.712491  0.440325    6.483944
# 2  0.154336  44.753664      97.63  1.985215  1.246336  0.347230   11.621024
# 3  0.152092  44.831238      98.19  2.000514  1.168762  0.282511   10.981692
# 4  0.164697  44.864405      98.67  2.002432  1.135595  0.435999   10.680281
#
#    FeO_calc  O=F,Cl  Total_recalc  Total Fail Msg  Input_Check  Mgno_Fe2  \
# 0  4.208078    -0.0     99.240825    NaN                  True  0.868273
# 1  3.605665    -0.0     99.347182    NaN                  True  0.885676
# 2  2.913255    -0.0    100.779493    NaN                  True  0.899146
# 3  2.388533    -0.0    101.290739    NaN                  True  0.918743
# 4  3.689747    -0.0    101.742460    NaN                  True  0.872857
#
#     Na_calc  B_Sum     A_Sum class           classification
# 0  0.258108    2.0  0.717443   N/A           Mg-hastingsite
# 1  0.194505    2.0  0.757125   N/A           Mg-hastingsite
# 2  0.363048    2.0  0.165110   N/A            Mg-Hornblende
# 3  0.328591    2.0  0.234784   N/A  Tschermakitic pargasite
# 4  0.363498    2.0  0.202943   N/A  Tschermakitic pargasite

# %%
plt.plot(Sites['Al_IV_T'], my_input['AlIV'], 'ok')

# %%
plt.plot(Sites['Al_IV_T'], my_input['AlIV'], 'ok')

# %% [markdown]
# ## Testing Water
# - Spreadsheet is doing different things in differnt places, referencing the 13 cation cells for your data, referencing their site cells otherwise.

# %%
NNO_Calc=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Ridolfi21").deltaNNO_calc
plt.plot(my_input['ΔNNO'], NNO_Calc, 'ok')

# %%
H2O_Calc=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Ridolfi21").H2O_calc
plt.plot(H2O_Calc.iloc[0:70], my_input['H2Omelt (wt%)'].iloc[0:70], 'ok')

# %%
H2O_Calc.iloc[]

# %%
a=pt.calculate_amp_only_press(amp_comps=myAmps1, equationP="P_Ridolfi2021")
a.to_clipboard(excel=True)

# %%
## Need some IF statements for Ridolfi
1) Sum <90, Low Total
If BG126 reads "lot total", or high total, print Wrong
If BG126 reads "unbalanced", wrong
If reads low MG, WRong,
IF low Ca, WRong
If high Ca, wrong
if BJ126>60
BG126 -low B cations - wrong. Else, okay. 

So want first, column Pass/Fail. Autofill with Pass. 
and a second column for "Reason" which gives ones above. Autofill with N/A

# %%
## First off, column BA (total)<98.5 = Low total. 
Ned column Az, Ba
