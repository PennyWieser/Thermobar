# %% [markdown]
# # This workbook compares the results from Thermobar to the supplemenary spreadsheet of Zhang et al. (2017)
# - The tiny discrepencies (~0.001 wt%) result from differences in molar masses. These are insignificant considering the error on coefficients

# %%
import numpy as np
import pandas as pd
import Thermobar as pt#
pd.options.display.max_columns = None
pd.options.display.max_rows = None
import matplotlib.pyplot as plt

# %%
# This dataset contains a lot of amphiboles which throw up errors
import warnings as w
with w.catch_warnings():
    w.simplefilter('ignore')
    out=pt.import_excel('Zhang_Supp2_Testing.xlsx', sheet_name="For_Thermobar")
    my_input=out['my_input']
    myAmps1=out['Amps']
    myLiquids1=out['Liqs']

# %% [markdown]
# ## Equation 1
# - Slight differences due to differences in molar masses on 2nd to 3rd decimal place. Well wtihin erorr.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Si_eq1=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17").SiO2_Eq1
ax1.plot(Si_eq1, my_input['wt% SiO2 eq1'], 'ok')
ax1.set_xlabel('Si Eq 1 Thermobar (wt%)')
ax1.set_ylabel('Si Eq 1 Supplement (wt%)')
                               
ax2.plot(Si_eq1, my_input['wt% SiO2 eq1']-Si_eq1, 'ok')
ax2.set_xlabel('Si Eq 1 Thermobar (wt%)')
ax2.set_ylabel('Si Suppelment-Thermobar (wt%)')
fig.tight_layout()
# Out:
# c:\users\penny\onedrive - oregon state university\postdoc\pymme\mybarometers\thermobar_outer\src\Thermobar\amphibole.py:173: UserWarning: You must enter a value for T in Kelvin to get results from equation3
#   w.warn('You must enter a value for T in Kelvin to get results from equation3')

# %% [markdown]
# ## Equation 2 - SiO2 content

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Si_eq2=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17").SiO2_Eq2
ax1.plot(Si_eq2, my_input['wt% SiO2 eq2'], 'ok')
ax1.set_xlabel('Si Eq 2 Thermobar (wt%)')
ax1.set_ylabel('Si Eq 2 Supplement (wt%)')
                               
ax2.plot(Si_eq2, my_input['wt% SiO2 eq2']-Si_eq2, 'ok')
ax2.set_xlabel('Si Eq 2 Thermobar (wt%)')
ax2.set_ylabel('Si Suppelment-Thermobar (wt%)')
fig.tight_layout()
# Out:
# c:\users\penny\onedrive - oregon state university\postdoc\pymme\mybarometers\thermobar_outer\src\Thermobar\amphibole.py:173: UserWarning: You must enter a value for T in Kelvin to get results from equation3
#   w.warn('You must enter a value for T in Kelvin to get results from equation3')

# %% [markdown]
# ## Equation 3 - SiO2

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Si_eq3=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).SiO2_Eq3
ax1.plot(Si_eq3, my_input['wt% SiO2 (T) eq3'], 'ok')
ax1.set_xlabel('Si Eq 3 Thermobar (wt%)')
ax1.set_ylabel('Si Eq 3 Supplement (wt%)')
                               
ax2.plot(Si_eq3, my_input['wt% SiO2 (T) eq3']-Si_eq3, 'ok')
ax2.set_xlabel('Si Eq 3 Thermobar (wt%)')
ax2.set_ylabel('Si Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 4 SiO2

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Si_eq4=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17").SiO2_Eq4
ax1.plot(Si_eq4, my_input['wt% SiO2 eq4'], 'ok')
ax1.set_xlabel('Si Eq 4 Thermobar (wt%)')
ax1.set_ylabel('Si Eq 4 Supplement (wt%)')
                               
ax2.plot(Si_eq4, my_input['wt% SiO2 eq4']-Si_eq4, 'ok')
ax2.set_xlabel('Si Eq 4 Thermobar (wt%)')
ax2.set_ylabel('Si Suppelment-Thermobar (wt%)')
fig.tight_layout()
# Out:
# c:\users\penny\onedrive - oregon state university\postdoc\pymme\mybarometers\thermobar_outer\src\Thermobar\amphibole.py:173: UserWarning: You must enter a value for T in Kelvin to get results from equation3
#   w.warn('You must enter a value for T in Kelvin to get results from equation3')

# %% [markdown]
# ## Equation 5 - TiO2

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Ti_eq5=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).TiO2_Eq5
ax1.plot(Ti_eq5, my_input['wt% TiO2 eq5'], 'ok')
ax1.set_xlabel('Ti Eq 5 Thermobar (wt%)')
ax1.set_ylabel('Ti Eq 5 Supplement (wt%)')
                               
ax2.plot(Ti_eq5, my_input['wt% TiO2 eq5']-Ti_eq5, 'ok')
ax2.set_xlabel('Ti Eq 5 Thermobar (wt%)')
ax2.set_ylabel('Ti Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 6 TiO2

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Ti_eq6=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).TiO2_Eq6
ax1.plot(Ti_eq6, my_input['wt% TiO2 eq6'], 'ok')
ax1.set_xlabel('Ti Eq 6 Thermobar (wt%)')
ax1.set_ylabel('Ti Eq 6 Supplement (wt%)')
                               
ax2.plot(Ti_eq6, my_input['wt% TiO2 eq6']-Ti_eq6, 'ok')
ax2.set_xlabel('Ti Eq 6 Thermobar (wt%)')
ax2.set_ylabel('Ti Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 7 FeO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Fe_eq7=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).FeO_Eq7
ax1.plot(Fe_eq7, my_input['wt% FeO eq7'], 'ok')
ax1.set_xlabel('Fe Eq 7 Thermobar (wt%)')
ax1.set_ylabel('Fe Eq 7 Supplement (wt%)')
                               
ax2.plot(Fe_eq7, my_input['wt% FeO eq7']-Fe_eq7, 'ok')
ax2.set_xlabel('Fe Eq 7 Thermobar (wt%)')
ax2.set_ylabel('Fe Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 8 FeO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Fe_eq8=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).FeO_Eq8
ax1.plot(Fe_eq8, my_input['wt% FeO eq8'], 'ok')
ax1.set_xlabel('Fe Eq 8 Thermobar (wt%)')
ax1.set_ylabel('Fe Eq 8 Supplement (wt%)')
                               
ax2.plot(Fe_eq8, my_input['wt% FeO eq8']-Fe_eq8, 'ok')
ax2.set_xlabel('Fe Eq 8 Thermobar (wt%)')
ax2.set_ylabel('Fe Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 9

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Fe_eq9=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).MgO_Eq9
ax1.plot(Fe_eq9, my_input['wt% MgO eq9'], 'ok')
ax1.set_xlabel('Fe Eq 8 Thermobar (wt%)')
ax1.set_ylabel('Fe Eq 8 Supplement (wt%)')
                               
ax2.plot(Fe_eq9, my_input['wt% MgO eq9']-Fe_eq9, 'ok')
ax2.set_xlabel('Fe Eq 8 Thermobar (wt%)')
ax2.set_ylabel('Fe Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 10 - CaO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Ca_eq10=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).CaO_Eq10
ax1.plot(Ca_eq10, my_input['wt% CaO eq10'], 'ok')
ax1.set_xlabel('Ca Eq 10 Thermobar (wt%)')
ax1.set_ylabel('Ca Eq 10 Supplement (wt%)')
                               
ax2.plot(Ca_eq10, my_input['wt% CaO eq10']-Ca_eq10, 'ok')
ax2.set_xlabel('Ca Eq 10 Thermobar (wt%)')
ax2.set_ylabel('Ca Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 11 CaO

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11,5))
Ca_eq11=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).CaO_Eq11
ax1.plot(Ca_eq11, my_input['wt% CaO eq11'], 'ok')
ax1.set_xlabel('Ca Eq 11 Thermobar (wt%)')
ax1.set_ylabel('Ca Eq 11 Supplement (wt%)')
                               
ax2.plot(Ca_eq11, my_input['wt% CaO eq11']-Ca_eq11, 'ok')
ax2.set_xlabel('Ca Eq 11 Thermobar (wt%)')
ax2.set_ylabel('Ca Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 12 - K2O

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
K2_eq12=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).K2O_Eq12
ax1.plot(K2_eq12, my_input['wt% K2O eq12'], 'ok')
ax1.set_xlabel('K2 Eq 12 Thermobar (wt%)')
ax1.set_ylabel('K2 Eq 12 Supplement (wt%)')
                               
ax2.plot(K2_eq12, my_input['wt% K2O eq12']-K2_eq12, 'ok')
ax2.set_xlabel('K2 Eq 12 Thermobar (wt%)')
ax2.set_ylabel('K2 Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 13 - K2O

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
K2_eq13=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).K2O_Eq13
ax1.plot(K2_eq13, my_input['wt% K2O eq13'], 'ok')
ax1.set_xlabel('K2 Eq 13 Thermobar (wt%)')
ax1.set_ylabel('K2 Eq 13 Supplement (wt%)')
                               
ax2.plot(K2_eq13, my_input['wt% K2O eq13']-K2_eq13, 'ok')
ax2.set_xlabel('K2 Eq 13 Thermobar (wt%)')
ax2.set_ylabel('K2 Suppelment-Thermobar (wt%)')
fig.tight_layout()

# %% [markdown]
# ## Equation 14- Al2O3

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
Al_eq14=pt.calculate_amp_only_melt_comps(amp_comps=myAmps1, equation="Zhang17", T_K=my_input['T_C']+273.15).Al2O3_Eq14
ax1.plot(Al_eq14, my_input['wt% Al2O3 eq14'], 'ok')
ax1.set_xlabel('Al Eq 14 Thermobar (wt%)')
ax1.set_ylabel('Al Eq 14 Supplement (wt%)')
                               
ax2.plot(Al_eq14, my_input['wt% Al2O3 eq14']-Al_eq14, 'ok')
ax2.set_xlabel('Al Eq 14 Thermobar (wt%)')
ax2.set_ylabel('Al Suppelment-Thermobar (wt%)')
fig.tight_layout()
