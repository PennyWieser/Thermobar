# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import Thermobar as pt
import re

# %%
df_Cpx=pd.read_excel('Thorn2026_Data.xlsx', sheet_name='Cpx_neat')
df_Liq=pd.read_excel('Thorn2026_Data.xlsx', sheet_name='Glass_neat')
# Merge
merged_df = pd.merge(df_Cpx, df_Liq, on='Run', how='inner')

# %%
merged_df.to_clipboard(excel=True)

# %%
out=pt.import_excel('Thorn2026_Data.xlsx', sheet_name='S3 - Clinopyroxene')

# %%
    Combo_liq_cpxs['Kd_Ideal_FeT_Thorn2026']=(-1
    +2.129* (T-273.15)/1000
    -1.675 *((liq_comps_c['Mgno_Cpx']))
    +0.144* (1/(1-liq_comps_c['Fe3Fet_Liq'])))
