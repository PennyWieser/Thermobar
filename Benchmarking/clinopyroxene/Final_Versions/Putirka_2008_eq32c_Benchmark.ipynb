# %% [markdown]
# ## This file benchmarks to the default option for eq32c from the Putirka (2008) spreadsheet
# - At the moment, the 1st cell in the spreadsheet references a different temperature column than the rest of the cells, so we return 2 values

# %%
import numpy as np
import pandas as pd
import Thermobar as pt
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import warnings as w
pd.options.display.max_columns = None

# %%
out=pt.import_excel('Putirka_2008_eq32c_default_Benchmark.xlsx', sheet_name='Thermobar_input')
myCpxs1=out['Cpxs']
myLiquids1=out['Liqs']
my_input=out['my_input']

# %%
All_Eqs=pt.calculate_cpx_liq_press_all_eqs(cpx_comps=myCpxs1, liq_comps=myLiquids1)
# Out:
# We have reset the index on Cpx and Liq comps for the Petrelli expressions
# Youve selected a P-independent function
# Youve selected a T-independent function
# Youve selected a T-independent function

# %%
plt.plot(All_Eqs['P_kbar: (P_Put2008_eq32c, default spreadsheet 1st cell)'].iloc[0],
        my_input['Spreadsheet_Calc'].iloc[0], 'ok')
plt.plot([5, 13], [5, 13], '-r')

# %%
plt.plot(All_Eqs['P_kbar: (P_Put2008_eq32c, default spreadsheet 2 on)'].iloc[1:],
        my_input['Spreadsheet_Calc'].iloc[1:], 'ok')
plt.plot([5, 13], [5, 13], '-r')
