# %% [markdown]
# # This compares the melt matching algorithms here to the results from the supporting spreadsheet of Neave et al. 2019 (see Melt_Matching_Example_Neave.xlsx)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import Thermobar as pt

# %%
out=pt.import_excel('Melt_Matching_Example_Neave.xlsx', sheet_name="Melts", suffix='_Liq')
out2=pt.import_excel('Melt_Matching_Example_Neave.xlsx', sheet_name="Cpxs", suffix='_Cpx')
my_input=out['my_input']
myCpxs1=out2['Cpxs']
myLiquids1=out['Liqs']

# %% [markdown]
# # Example, making dataframe of matches

# %%
# One way to get dataframe out to paste in
Combo_liq_cpxs=pt.calculate_cpx_liq_press_temp_matching(liq_comps=myLiquids1, cpx_comps=myCpxs1, 
                                                equationP="P_Neave2017", equationT="T_Put2008_eq33",
                                                        return_all_pairs=True)
# Out:
# Considering N=5 Cpx & N=8 Liqs, which is a total of N=40 Liq-Cpx pairs, be patient if this is >>1 million!
# No equilibrium filters applied
# Finished calculating Ps and Ts, now just averaging the results. Almost there!
# Done!!! I found a total of N=40 Cpx-Liq matches using the specified filter. N=5 Cpx out of the N=5 Cpx that you input matched to 1 or more liquids

# %%
All=Combo_liq_cpxs['All_PTs']
#Neave tests
NT=pd.read_excel('Melt_Matching_Example_Neave.xlsx', sheet_name='Tests')

# %%
All.columns[0:100]
# Out:
# Index(['Sample_ID_Cpx', 'P_kbar_calc', 'T_K_calc', 'Delta_T_K_Iter',
#        'Delta_P_kbar_Iter', 'Eq Tests Neave2017?', 'Delta_Kd_Put2008',
#        'Delta_Kd_Mas2013', 'Delta_EnFs_Mollo13', 'Delta_EnFs_Put1999',
#        'Delta_CaTs_Put1999', 'Delta_DiHd_Mollo13', 'Delta_DiHd_Put1999',
#        'Delta_CrCaTs_Put1999', 'Delta_CaTi_Put1999', 'SiO2_Liq', 'TiO2_Liq',
#        'Al2O3_Liq', 'FeOt_Liq', 'MnO_Liq', 'MgO_Liq', 'CaO_Liq', 'Na2O_Liq',
#        'K2O_Liq', 'Cr2O3_Liq', 'P2O5_Liq', 'H2O_Liq', 'Fe3Fet_Liq', 'NiO_Liq',
#        'CoO_Liq', 'CO2_Liq', 'SiO2_Liq_mol_frac', 'MgO_Liq_mol_frac',
#        'MnO_Liq_mol_frac', 'FeOt_Liq_mol_frac', 'CaO_Liq_mol_frac',
#        'Al2O3_Liq_mol_frac', 'Na2O_Liq_mol_frac', 'K2O_Liq_mol_frac',
#        'TiO2_Liq_mol_frac', 'P2O5_Liq_mol_frac', 'Cr2O3_Liq_mol_frac',
#        'Si_Liq_cat_frac', 'Mg_Liq_cat_frac', 'Mn_Liq_cat_frac',
#        'Fet_Liq_cat_frac', 'Ca_Liq_cat_frac', 'Al_Liq_cat_frac',
#        'Na_Liq_cat_frac', 'K_Liq_cat_frac', 'Ti_Liq_cat_frac',
#        'P_Liq_cat_frac', 'Cr_Liq_cat_frac', 'Mg_Number_Liq_NoFe3',
#        'Mg_Number_Liq_Fe3', 'ID_Liq', 'SiO2_Cpx', 'TiO2_Cpx', 'Al2O3_Cpx',
#        'FeOt_Cpx', 'MnO_Cpx', 'MgO_Cpx', 'CaO_Cpx', 'Na2O_Cpx', 'K2O_Cpx',
#        'Cr2O3_Cpx', 'Si_Cpx_cat_6ox', 'Mg_Cpx_cat_6ox', 'Fet_Cpx_cat_6ox',
#        'Ca_Cpx_cat_6ox', 'Al_Cpx_cat_6ox', 'Na_Cpx_cat_6ox', 'K_Cpx_cat_6ox',
#        'Mn_Cpx_cat_6ox', 'Ti_Cpx_cat_6ox', 'Cr_Cpx_cat_6ox',
#        'oxy_renorm_factor', 'Al_IV_cat_6ox', 'Al_VI_cat_6ox',
#        'En_Simple_MgFeCa_Cpx', 'Fs_Simple_MgFeCa_Cpx', 'Wo_Simple_MgFeCa_Cpx',
#        'Cation_Sum_Cpx', 'Ca_CaMgFe', 'Lindley_Fe3_Cpx', 'Lindley_Fe2_Cpx',
#        'Lindley_Fe3_Cpx_prop', 'CrCaTs', 'a_cpx_En', 'Mgno_Cpx', 'Jd',
#        'Jd_from 0=Na, 1=Al', 'CaTs', 'CaTi', 'DiHd_1996', 'EnFs', 'DiHd_2003',
#        'Di_Cpx', 'FeIII_Wang21', 'FeII_Wang21'],
#       dtype='object')

# %%
Combo_liq_cpxs2=pt.calculate_cpx_liq_press_temp_matching(liq_comps=myLiquids1, cpx_comps=myCpxs1, 
                                                equationP="P_Put1996_eqP1", equationT="T_Put2008_eq33",
                                                        return_all_pairs=True)


All2=Combo_liq_cpxs2['All_PTs']
test='ΔCaTi'
plt.plot(All2['Delta_CaTi_Put1999'], NT[test], 'ok')
plt.plot([min(NT[test]), max(NT[test])],
          [min(NT[test]), max(NT[test])],
           '-r')
plt.xlabel(test + ' Neave')
plt.ylabel('Thermobar')
# Out:
# Considering N=5 Cpx & N=8 Liqs, which is a total of N=40 Liq-Cpx pairs, be patient if this is >>1 million!
# No equilibrium filters applied
# Finished calculating Ps and Ts, now just averaging the results. Almost there!
# Done!!! I found a total of N=40 Cpx-Liq matches using the specified filter. N=5 Cpx out of the N=5 Cpx that you input matched to 1 or more liquids
# Text(0, 0.5, 'Thermobar')

# %%
test='ΔCrCaTs'
plt.plot(All['Delta_CrCaTs_Put1999'], NT[test], 'ok')
plt.plot([min(NT[test]), max(NT[test])],
          [min(NT[test]), max(NT[test])],
           '-r')
plt.xlabel(test + ' Neave')
plt.ylabel('Thermobar')
# Out:
# Text(0, 0.5, 'Thermobar')

# %%
test='ΔCaTs'
plt.plot(All['Delta_CaTs_Put1999'], NT[test], 'ok')
plt.plot([min(NT[test]), max(NT[test])],
          [min(NT[test]), max(NT[test])],
           '-r')
plt.xlabel(test + ' Neave')
plt.ylabel('Thermobar')
# Out:
# Text(0, 0.5, 'Thermobar')

# %%
test='ΔCaTs'
plt.plot(All['Delta_CaTs_Put1999'], NT[test], 'ok')
plt.plot([min(NT[test]), max(NT[test])],
          [min(NT[test]), max(NT[test])],
           '-r')
plt.xlabel(test + ' Neave')
plt.ylabel('Thermobar')
# Out:
# Text(0, 0.5, 'Thermobar')

# %%
test='ΔEnFs'
plt.plot(All['Delta_EnFs_Mollo13'], NT[test], 'ok')
plt.plot([min(NT[test]), max(NT[test])],
          [min(NT[test]), max(NT[test])],
           '-r')
plt.xlabel(test + ' Neave')
plt.ylabel('Thermobar')
# Out:
# Text(0, 0.5, 'Thermobar')

# %%
All.columns
# Out:
# Index(['Sample_ID_Cpx', 'P_kbar_calc', 'T_K_calc', 'Delta_T_K_Iter',
#        'Delta_P_kbar_Iter', 'Eq Tests Neave2017?', 'Delta_Kd_Put2008',
#        'Delta_Kd_Mas2013', 'Delta_EnFs_Mollo13', 'Delta_EnFs_Put1999',
#        ...
#        'CaTs_Pred_Put1999', 'Delta_CaTs_I_M_Put1999', 'CrCaTs_Pred_Put1999',
#        'Delta_CrCaTs_I_M_Put1999', 'CaTi_Pred_Put1999',
#        'Delta_CaTi_I_M_Put1999', 'Jd_Pred_Put1999', 'Delta_Jd_Put1999',
#        'Delta_Jd_I_M_Put1999', 'Sample_ID_Liq'],
#       dtype='object', length=134)

# %%
#Second way to do this
myCPXs1_concat=myCpxs1
myLiquids1_concat=myLiquids1
DupCPXs = pd.DataFrame(np.repeat(myCPXs1_concat.values,np.shape(myLiquids1_concat)[0],axis=0))
    #.astype('float64') 
DupCPXs.columns = myCPXs1_concat.columns 

DupLiqs=pd.concat([myLiquids1_concat]*np.shape(myCPXs1_concat)[0]).reset_index(drop=True) 
Combo_liq_cpxs=pd.concat([DupLiqs, DupCPXs], axis=1) # Combines these merged liquids and cpx dataframes

# %%
# This copies the output to excel to paste into Neave's spreadsheet
Combo_liq_cpxs.to_clipboard(excel=True)

# %%
# See Sheet "Cpx Input and Models" of Putirka, se that get no matches with default criteria
melt_match_out=pt.calculate_cpx_liq_press_temp_matching(liq_comps=myLiquids1, cpx_comps=myCpxs1, 
                                                equationP="P_Neave2017", equationT="T_Put2008_eq33", Kd_Err=0.03,
                                                       Fe3Fet_Liq=0.0)

AvMatches_Gleeson_NoFe3=melt_match_out['Av_PTs']
AllMatches_Gleeson_NoFe3=melt_match_out['All_PTs']
# Out:
# Considering 40 Liq-Cpx pairs, be patient if this is >>1 million!
# 0 Matches remaining after initial Kd filter. Now moving onto iterative calculations
# Finished calculating Ps and Ts, now just averaging the results. Almost there!
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-d5e4e8bb2923> in <module>
#       1 # See Sheet "Cpx Input and Models" of Putirka, se that get no matches with default criteria
# ----> 2 melt_match_out=pt.calculate_cpx_liq_press_temp_matching(liq_comps=myLiquids1, cpx_comps=myCpxs1,
#       3                                                 equationP="P_Neave2017", equationT="T_Put2008_eq33", Kd_Err=0.03,
#       4                                                        Fe3Fet_Liq=0.0)
#       5
#
# c:\users\penny\onedrive - oregon state university\postdoc\pymme\mybarometers\thermobar_outer\src\Thermobar\clinopyroxene_thermobarometry.py in calculate_cpx_liq_press_temp_matching(liq_comps, cpx_comps, equationT, equationP, P, T, PMax, Fe3Fet_Liq, Kd_Match, Kd_Err, DiHd_Err, EnFs_Err, CaTs_Err, Cpx_Quality, H2O_Liq, return_all_pairs)
#    1441
#    1442     else:
# -> 1443         raise Exception(
#    1444             'No Matches - to set less strict filters, change perhaps change sigma to a value greater'
#    1445             ' than one, or specify eq_crit for only a subset of the values in Neave and Putirka')
#
# Exception: No Matches - to set less strict filters, change perhaps change sigma to a value greater than one, or specify eq_crit for only a subset of the values in Neave and Putirka

# %%
# Say set Kd filter to 0.06, see Sheet "Cpx Input and Models_2" of Putirka, se that get no matches with default criteria
melt_match_out=pt.calculate_cpx_liq_press_temp_matching(liq_comps=myLiquids1, cpx_comps=myCpxs1, 
                                                equationP="P_Neave2017", equationT="T_Put2008_eq33", Kd_Err=0.11,
                                                     Fe3Fet_Liq=0.0, 
                                                       DiHd_Err=0.06*4, EnFs_Err=4*0.05,
                                                       CaTs_Err=0.03*4)

AvMatches_Gleeson_NoFe3=melt_match_out['Av_PTs']
AllMatches_Gleeson_NoFe3=melt_match_out['All_PTs']
# Out:
# Considering 40 Liq-Cpx pairs, be patient if this is >>1 million!
# 40 Matches remaining after initial Kd filter. Now moving onto iterative calculations
# Finished calculating Ps and Ts, now just averaging the results. Almost there!
# Done!

# %%
AllMatches_Gleeson_NoFe3['T_C']=AllMatches_Gleeson_NoFe3['T_K_calc']-273.15
AllMatches_Gleeson_NoFe3['T_C']
# Out:
# 27    1206.889007
# 28    1208.285039
# 29    1208.338952
# 31    1204.959196
# 33    1205.889817
# 34    1203.927918
# 35    1206.209066
# 36    1207.602880
# 37    1207.656539
# 39    1204.282002
# Name: T_C, dtype: float64

# %% [markdown]
# # From Neave spreadsheet
# ![image.png](attachment:1e47ee15-0567-4c63-93af-9ede330e8077.png)

# %%
AllMatches_Gleeson_NoFe3['P_kbar_calc']
# Out:
# 27    5.993997
# 28    6.002878
# 29    6.060537
# 31    6.001705
# 33    6.032014
# 34    6.007048
# 35    5.860366
# 36    5.869089
# 37    5.926715
# 39    5.868240
# Name: P_kbar_calc, dtype: float64

# %% [markdown]
# - screengrab from Neave Supplement
# ![image.png](attachment:e099eb04-de2c-46e3-9cf1-a6d36bd4677d.png)
