# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf
pf.__version__
# Out:
# '0.0.38'

# %%
df=pd.read_excel('Rasmussen.xlsx')

# %%
df['P']=df['Pressure(MPa)']*0.01
df.head()
# Out:
#    Depth(km)  Pressure(MPa)         P
# 0   0.000000       0.000000  0.000000
# 1   0.100503       2.340557  0.023406
# 2   0.201005       4.688959  0.046890
# 3   0.301508       7.044404  0.070444
# 4   0.402010       9.405167  0.094052

# %%
plt.plot( df['Depth(km)'], df['P'], '.r')
plt.plot(0, 0, '.k')

# %%
np.max(xvar)
# Out:
# 5.2474630296099205

# %%
xvar=df['P']
yvar=df['Depth(km)']
Pf = np.poly1d(np.polyfit(xvar, yvar,
                          4))
Py = Pf(xvar)

# %%
plt.plot(Py, yvar, 'ok')

# %%
plt.plot(xvar, Py, '-k')
plt.plot(xvar, yvar, '.r')

# %%
plt.plot(xvar, 1000*(Py-yvar), 'or')
plt.xlabel('Pressure (kbar)')
plt.ylabel('offset (m)')
# Out:
# Text(0, 0.5, 'offset (m)')

# %%
Pf[1]
# Out:
# 4.273285349609203

# %%
Pf[0]
# Out:
# 0.00430844920014402

# %%
P=xvar
# Fitting a 4th order polynomail to the supplement
b=-0.0025915704129682504
c=0.037299399171806996
d=-0.21276925206828018
e=4.273285349609203
f=0.00430844920014402
D= b*(P**4) + c*(P**3) + d*(P**2) + e*P + f

# a=Pf[0]
# b=Pf[1]

# calc=b*(xvar) + a

# %%
xvar
# Out:
# 0      0.000000
# 1      0.023406
# 2      0.046890
# 3      0.070444
# 4      0.094052
#          ...
# 195    5.137559
# 196    5.165025
# 197    5.192496
# 198    5.219971
# 199    5.247463
# Name: P, Length: 200, dtype: float64

# %%
plt.plot(calc, calc-Py, 'or')

# %%
max(xvar)
# Out:
# 5.2474630296099205
