# %% [markdown]
# # Benchmarking Garnet functions

# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt
import Thermobar as pt

# %% [markdown]
# ## Load data from Ozaydin et al. (2021)

# %%
#Now load the data from 
file = "Group1_Kimberley.xlsx" #Wherever that /Examples/Garnet is
data = pt.import_excel(file, sheet_name = "Sheet1")
my_input_gt = data['Gts']

# %%
my_input_gt
# Out:
#       SiO2_Gt  TiO2_Gt  Al2O3_Gt  Cr2O3_Gt  FeOt_Gt  MnO_Gt  MgO_Gt  CaO_Gt  \
# 0       41.92     0.03     21.83      2.73     8.91    0.51   18.18    5.34
# 1       41.46     0.10     18.27      6.33     6.60    0.38   20.05    5.85
# 2       40.99     0.00     18.37      7.07     6.75    0.24   19.91    5.68
# 3       42.78     0.21     20.67      3.08     6.90    0.28   21.76    4.58
# 4       42.32     0.03     22.22      2.51     9.41    0.51   19.03    5.18
# ...       ...      ...       ...       ...      ...     ...     ...     ...
# 5515    41.96     0.00     19.88      4.73     6.59    0.27   21.07    4.83
# 5516    42.90     0.01     20.40      4.01     7.10    0.40   20.61    5.09
# 5517    41.85     0.00     20.84      3.91     6.81    0.23   21.23    4.95
# 5518    41.12     0.06     20.68      3.15     8.96    0.47   19.75    4.72
# 5519    41.93     0.00     21.09      3.22     8.79    0.37   19.48    4.80
#
#       Na2O_Gt  K2O_Gt   Ni_Gt        Ti_Gt  Zr_Gt  Zn_Gt   Ga_Gt  Sr_Gt  \
# 0        0.00       0    7.04   179.845333   1.20   2.31   2.110    0.0
# 1        0.02       0    8.03   599.484443  14.74   0.00   0.337    0.0
# 2        0.00       0    8.03     0.000000  14.74   0.00   0.337    0.0
# 3        0.00       0    8.21  1258.917331  20.11  15.64   6.120    0.0
# 4        0.12       0    8.25   179.845333   5.01   5.89   2.220    0.0
# ...       ...     ...     ...          ...    ...    ...     ...    ...
# 5515     0.00       0  227.10     0.000000  18.40   0.00   3.860    0.0
# 5516     0.01       0  280.75    59.948444  78.03   0.00   7.900    0.0
# 5517     0.04       0  280.75     0.000000  78.03   0.00   7.900    0.0
# 5518     0.05       0  317.01   359.690666  85.91   0.00  20.640    0.0
# 5519     0.07       0  317.01     0.000000  85.91   0.00  20.640    0.0
#
#         Y_Gt     Sample_ID_Gt
# 0     10.830   173/034/0021/2
# 1      2.091           EAK807
# 2      2.091           EAK807
# 3      2.390  173/033/K069/10
# 4      9.440   173/034/0021/2
# ...      ...              ...
# 5515   0.755           EAK807
# 5516   2.340           EAK807
# 5517   2.340           EAK807
# 5518  24.810           EAK807
# 5519  24.810           EAK807
#
# [5520 rows x 18 columns]

# %% [markdown]
# ## Calculating T from Ryan_1996

# %%
T = pt.calculate_gt_temp(gt_comps = my_input_gt, 
        equationT = 'T_Ryan1996') #Calculating T_Ryan1996
T
# Out:
# 0        879.394511
# 1        899.055711
# 2        899.055711
# 3        902.455158
# 4        903.203904
#            ...
# 5515    2080.727200
# 5516    2270.048658
# 5517    2270.048658
# 5518    2394.856217
# 5519    2394.856217
# Length: 5520, dtype: float64

# %% [markdown]
# ### Comparison with published data from Ozaydin et al. (2021)

# %%
#Loading external file including the solution from 
file_ext = "Group_1_PT_solution.xlsx"
data_ext = pt.import_excel(file_ext, sheet_name = "Group_1_PT_solution")
input_gt_ext = data_ext['my_input']
p_ext = np.array(input_gt_ext['P_Kb'])
t_ext = np.array(input_gt_ext['T_C'] + 273)

# %%
#Creating fig object
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

ax1.plot([1000, 2500], [1000, 2500],color = 'r',linewidth = 1)



#plotting calculated vs read T_Ryan1996
ax1.plot(t_ext,T, 'o')

ax2.plot(t_ext, t_ext-T, 'ok')
ax2.set_yticks([-0.05, 0, 0.05])

ax1.set_ylabel('T Thermobar')
ax1.set_xlabel('T Published')


ax2.set_ylabel('T Published-T Thermobar')
ax2.set_xlabel('T Published')
fig.tight_layout()

# %% [markdown]
# ## Calculating P from Ryan 1996

# %%
P = pt.calculate_gt_press(gt_comps = my_input_gt, equationP = 'P_Ryan1996', 
                        T = T)
P
# Out:
# c:\users\penny\onedrive - oregon state university\postdoc\pymme\mybarometers\thermobar_outer\src\Thermobar\core.py:1017: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gt_comps['TiO2_Gt'][i] = (gt_comps['Ti_Gt'][i] * 1.6685) / 1e4
# 0       21.997736
# 1       34.305015
# 2       35.574086
# 3       28.746510
# 4       22.092332
#           ...
# 5515    41.244365
# 5516    21.231356
# 5517    20.578851
# 5518    84.851620
# 5519    84.191790
# Length: 5520, dtype: float64

# %%
#Creating fig object
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

ax1.plot([0, 100], [0, 100],color = 'r',linewidth = 1)



#plotting calculated vs read T_Ryan1996
ax1.plot(p_ext,P, 'o')

ax2.plot(p_ext, p_ext-P, 'ok')
#ax2.set_yticks([-0.05, 0, 0.05])

ax1.set_ylabel('P Thermobar')
ax1.set_xlabel('P Published')


ax2.set_ylabel('P Published - P Thermobar')
ax2.set_xlabel('P Published')
fig.tight_layout()

# %% [markdown]
# ## Sudholz et al. 2021

# %%
#Loading data from Sudholz et al. (2021) for benchmarking tests of
#Sudholz2021 and Canil1999. This file consists both the solution and composition data
file_sudholz = "PT_Sudholz.xlsx"
data_sudholz = pt.import_excel(file_sudholz, sheet_name = "PT_Sudholz")
input_sudholz_ext = data_sudholz['my_input']

# %%
T2 = pt.calculate_gt_temp(gt_comps = input_sudholz_ext, equationT = 'T_Sudholz2021')

# %%
T=T2
t_ext=input_sudholz_ext['T_Sudholz']+273.15
#Creating fig object
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

ax1.plot([1000, 2500], [1000, 2500],color = 'r',linewidth = 1)



#plotting calculated vs read T_Ryan1996
ax1.plot(t_ext,T, 'o')

ax2.plot(t_ext, t_ext-T, 'ok')
ax2.set_yticks([-0.25, 0, 0.25])

ax1.set_ylabel('T Thermobar')
ax1.set_xlabel('T Published')


ax2.set_ylabel('T Published-T Thermobar')
ax2.set_xlabel('T Published')
fig.tight_layout()

# %% [markdown]
# ## Canil et al. 1999

# %%
T3 = pt.calculate_gt_temp(gt_comps = input_sudholz_ext, equationT = 'T_Canil1999')

# %%
T=T3
t_ext=input_sudholz_ext['T_Canil']+273.15
#Creating fig object
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

ax1.plot([1000, 2500], [1000, 2500],color = 'r',linewidth = 1)



#plotting calculated vs read T_Ryan1996
ax1.plot(t_ext,T, 'o')

ax2.plot(t_ext, t_ext-T, 'ok')
ax2.set_yticks([-0.25, 0, 0.25])

ax1.set_ylabel('T Thermobar')
ax1.set_xlabel('T Published')


ax2.set_ylabel('T Published-T Thermobar')
ax2.set_xlabel('T Published')
fig.tight_layout()

# %% [markdown]
# ## Example of plotting functions

# %%
#These are not benchmarking tests but an example for plotting functions
pt.plot_CA_CR(gt_comps = my_input_gt, T_Ni = T, P_Cr = P, BDL_T = 1125,
 SHF_low = 35, SHF_high = 45, SHF_chosen = 37, max_depth = 300,
  temp_unit = 'Celsius', plot_type = 'show')

# %%
my_input_gt
# Out:
#       SiO2_Gt   TiO2_Gt  Al2O3_Gt  Cr2O3_Gt  FeOt_Gt  MnO_Gt  MgO_Gt  CaO_Gt  \
# 0       41.92  0.030007     21.83      2.73     8.91    0.51   18.18    5.34
# 1       41.46  0.100024     18.27      6.33     6.60    0.38   20.05    5.85
# 2       40.99  0.000000     18.37      7.07     6.75    0.24   19.91    5.68
# 3       42.78  0.210050     20.67      3.08     6.90    0.28   21.76    4.58
# 4       42.32  0.030007     22.22      2.51     9.41    0.51   19.03    5.18
# ...       ...       ...       ...       ...      ...     ...     ...     ...
# 5515    41.96  0.000000     19.88      4.73     6.59    0.27   21.07    4.83
# 5516    42.90  0.010002     20.40      4.01     7.10    0.40   20.61    5.09
# 5517    41.85  0.000000     20.84      3.91     6.81    0.23   21.23    4.95
# 5518    41.12  0.060014     20.68      3.15     8.96    0.47   19.75    4.72
# 5519    41.93  0.000000     21.09      3.22     8.79    0.37   19.48    4.80
#
#       Na2O_Gt  K2O_Gt   Ni_Gt        Ti_Gt  Zr_Gt  Zn_Gt   Ga_Gt  Sr_Gt  \
# 0        0.00       0    7.04   179.845333   1.20   2.31   2.110    0.0
# 1        0.02       0    8.03   599.484443  14.74   0.00   0.337    0.0
# 2        0.00       0    8.03     0.000000  14.74   0.00   0.337    0.0
# 3        0.00       0    8.21  1258.917331  20.11  15.64   6.120    0.0
# 4        0.12       0    8.25   179.845333   5.01   5.89   2.220    0.0
# ...       ...     ...     ...          ...    ...    ...     ...    ...
# 5515     0.00       0  227.10     0.000000  18.40   0.00   3.860    0.0
# 5516     0.01       0  280.75    59.948444  78.03   0.00   7.900    0.0
# 5517     0.04       0  280.75     0.000000  78.03   0.00   7.900    0.0
# 5518     0.05       0  317.01   359.690666  85.91   0.00  20.640    0.0
# 5519     0.07       0  317.01     0.000000  85.91   0.00  20.640    0.0
#
#         Y_Gt     Sample_ID_Gt
# 0     10.830   173/034/0021/2
# 1      2.091           EAK807
# 2      2.091           EAK807
# 3      2.390  173/033/K069/10
# 4      9.440   173/034/0021/2
# ...      ...              ...
# 5515   0.755           EAK807
# 5516   2.340           EAK807
# 5517   2.340           EAK807
# 5518  24.810           EAK807
# 5519  24.810           EAK807
#
# [5520 rows x 18 columns]

# %%
my_input_gt = data['my_input']

# %%
pt.plot_garnet_composition_section(gt_comps = my_input_gt, depth_interval = 10,
min_section_depth = 50, max_section_depth = 300, T_Ni = T, P_Cr = P, BDL_T = 1125,
 SHF_low = 35, SHF_high = 45, SHF_chosen = 37, temp_unit = 'Celsius',
 plot_type = 'show', filename_save = 'CARP_plot_2')
# Out:
# c:\users\penny\onedrive - oregon state university\postdoc\pymme\mybarometers\thermobar_outer\src\Thermobar\core.py:1017: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gt_comps['TiO2_Gt'][i] = (gt_comps['Ti_Gt'][i] * 1.6685) / 1e4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [26], in <module>
# ----> 1 pt.plot_garnet_composition_section(gt_comps = my_input_gt, depth_interval = 10,
#       2 min_section_depth = 50, max_section_depth = 300, T_Ni = T, P_Cr = P, BDL_T = 1125,
#       3  SHF_low = 35, SHF_high = 45, SHF_chosen = 37, temp_unit = 'Celsius',
#       4  plot_type = 'show', filename_save = 'CARP_plot_2')
#
# File c:\users\penny\onedrive - oregon state university\postdoc\pymme\mybarometers\thermobar_outer\src\Thermobar\garnet_plot.py:287, in plot_garnet_composition_section(gt_comps, depth_interval, min_section_depth, max_section_depth, T_Ni, P_Cr, BDL_T, SHF_low, SHF_high, SHF_chosen, temp_unit, plot_type, filename_save)
#     285 cacr_class = garnet_ca_cr_class_Griffin2002(gt_comps = gt_comps)
#     286 g_class = garnet_class_Grutter2003(gt_comps = gt_comps)
# --> 287 MG = calculate_ol_mg(gt_comps = gt_comps, T_Ni = T_Ni, xMg = xMg, xCa = xCa, xFe = xFe) #calculating olivine magnesium number from garnet composition
#     288 AL = calculate_al2o3_whole_rock(gt_comps = gt_comps) #calculating Al2O3 whole rock from garnet compostion
#     290 depth_normal = np.zeros(len(P_Cr))
#
# File c:\users\penny\onedrive - oregon state university\postdoc\pymme\mybarometers\thermobar_outer\src\Thermobar\garnet_class.py:560, in calculate_ol_mg(gt_comps, T_Ni, xMg, xCa, xFe)
#     556 T_Ni = np.array(T_Ni) - 273.0 #converting to celsius for calculations
#     558 for i in range(0,len(np.array(gt_comps['MgO_Gt']))):
# --> 560     p_calc = (0.00001786*(T_Ni[i]**2.0)) + (0.027419*T_Ni[i]) - 1.198
#     561     p1 = p_calc - (0.000263*(p_calc**2.0)) - 29.76
#     562     p2 = p_calc - (0.00039*(p_calc**2.0)) - 29.65
#
# IndexError: index 117 is out of bounds for axis 0 with size 117
